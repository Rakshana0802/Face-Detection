# %%
#import opencv
import cv2

#import matplotlib
import matplotlib.pyplot as plt

# %%
def plottingImg(image):
    plt.axis('off')
    plt.figure(figsize=(15,15))
    plt.imshow(image)
    plt.show()

# %%
def findFace(image):
    boxes = faceCascade.detectMultiScale(
        image,
        scaleFactor=1.2,
        minNeighbors=5,
        minSize=(50, 50)
        )
    return boxes

def drawBox(image, boxes):
    for (x,y,w,h) in boxes:
        cv2.rectangle(
            image, 
            (x,y), 
            (x+w,y+h), 
            (0,0,255), 
            5)
    return image

# %%
#path of 1st image
imagePath1 = "image1.jpg"
#reading the image
image1 = cv2.imread(imagePath1)
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

# %%
plottingImg(image1)

# %%
harpath="haarcascade_frontalface_default.xml"

# %%
faceCascade = cv2.CascadeClassifier(harpath)

faces=findFace(image1)
print("Found {0} Faces!".format(len(faces)))
# Out:
# Found 0 Faces!

# %%
image1 = drawBox(image1,faces)

# %%
plottingImg(image1)

# %% [markdown]
# Being a low resolution image, Haar Cascade is unable to detect all faces.

# %%
imagePath2 = "image2.jpg"

# %%
image2 = cv2.imread(imagePath2)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# %%
plottingImg(image2)

# %%
faces2=findFace(image2)

print("Found {0} Faces!".format(len(faces2)))
# Out:
# Found 6 Faces!

# %%
image2 = drawBox(image2,faces2)

# %%
plottingImg(image2)

# %% [markdown]
# Even with a Larger image, Haar Cascade struggles

# %%
imagePath3 = "facial_recognition/image3.jpg"

# %%
image3 = cv2.imread(imagePath3)
image3 = cv2.cvtColor(image3, cv2.COLOR_BGR2RGB)
plottingImg(image3)

# %%
faces3 = findFace(image3)

print("Found {0} Faces!".format(len(faces3)))

image3 = drawBox(image3,faces3)

plottingImg(image3)
# Out:
# Found 1 Faces!

# %% [markdown]
# So only for a Straight Face high defination image was perfectly detected by Haar Cascade
